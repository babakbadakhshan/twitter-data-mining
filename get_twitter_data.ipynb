# %% [markdown]
# <a href="https://colab.research.google.com/github/babakbadakhshan/twitter-data-mining/blob/main/get_twitter_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ntscraper

# %%
from ntscraper import Nitter
import pandas as pd

# %%
scraper = Nitter(0)
# Out:
# Testing instances: 100%|██████████| 16/16 [00:12<00:00,  1.25it/s]

# %%
tweets = scraper.get_tweets('پارک_لاله', mode='hashtag', number=2000)

# %%
final_tweets = []
for x in tweets['tweets']:
    data = [x['link'], x['text'],x['date'],x['stats']['likes'],x['stats']['comments']]
    final_tweets.append(data)
final_tweets = pd.DataFrame(final_tweets, columns=['link', 'text', 'date', 'likes', 'comments'])
final_tweets.head(5)
# Out:
#                                                 link  \
# 0  https://twitter.com/Elhammarvi/status/17312970...
# 1  https://twitter.com/Mohammad64karim/status/182...
# 2  https://twitter.com/SHIVAARASTEH/status/182661...
# 3  https://twitter.com/0misskei0/status/182649722...
# 4  https://twitter.com/KhatamAkram/status/1826460...
#
#                                                 text  \
# 0                        #پاییز در #پارک_لاله 📸by me
# 1  در حالی که هنوز حصار ساخت و سازی که کمیسیون شه...
# 2  ای خردمند عاقل و دانا قصه ی درخت و زاک برخوانا...
# 3                 زاکانی حروم زاده و شرکا #پارک_لاله
# 4  #زاکانی در حال ویران کردن زیباترین و بزرگترین ...
#
#                          date  likes  comments
# 0  Dec 3, 2023 · 12:59 PM UTC     21         0
# 1  Aug 19, 2024 · 5:52 PM UTC     23         0
# 2  Aug 22, 2024 · 1:27 PM UTC     69         0
# 3  Aug 22, 2024 · 5:50 AM UTC      3         1
# 4  Aug 22, 2024 · 3:26 AM UTC    276         2

# %%
final_tweets.to_csv('hormoz_tweets.csv')
